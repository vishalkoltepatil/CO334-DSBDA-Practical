# %%
# Kolte Vishal Nayabrao 
# CO334
# DSBDA 
# Third Year Computer Engg.


# Import the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Read the csv file
df = pd.read_csv("Student.csv")
df
# Out:
#    Roll No           Name of Student                        Email_ id  \
# 0    CO301       SHINDE KIRAN SATISH        shindekiran0120@gmail.com
# 1    CO302   BANDAL SAURABH HANUMANT        saurabhbandal04@gmail.com
# 2    CO303  BHOSALE AISHWARYA SANJAY  bhosaleaishwarya7070@gmail.com
# 3    CO304  BUNGE SAKSHI DNYANESHWAR            bungesakshi@gmail.com
# 4    CO305    CHAVAN PUSHPAK MAHADEV      pushpakchavan798@gmail.com
# ..     ...                       ...                              ...
# 67   CO368      KALYANKAR OMKAR AMAR        omkarkalyankar8@gmail.com
# 68   CO369        KUMBHAR ROHIT ANIL       rohitkumbhar6342@gmail.com
# 69   CO370       TOMPE ANUJA PRAKASH            tompeanuja@gmail.com
# 70   CO371     DANGE SAMIKSHA SANJAY      2018samikshadange@gmail.com
# 71   CO372    KAMBLE ABHISHEK SANJAY    abhishekkambale2018@gmail.com
#
#      Contact No.         DOB  \
# 0   9.322626e+09         NaN
# 1            NaN  04/09/2002
# 2   8.530153e+09  07/07/2002
# 3   9.579328e+09  04/05/2002
# 4   9.130664e+09  02/03/2002
# ..           ...         ...
# 67  7.057567e+09  15/11/2000
# 68  7.249466e+09  19/08/2002
# 69  9.156100e+09  18/06/2002
# 70  7.498195e+09         NaN
# 71  7.028331e+09  12/05/2000
#
#                                               Address  First year: Sem 1  \
# 0                                                 NaN               8.40
# 1           At Po Soratewadi, Tal Baramati, Dist Pune               8.14
# 2           at post wanewadi, tal-Baramati dist-pune                6.61
# 3                 A/P: Murum Tal. Baramati Dist Pune.               7.20
# 4              At Post Jejuri Tal-Purandar Dist-Pune                7.05
# ..                                                ...                ...
# 67  Station Road,Subhas Chowk,Opp.Chandan Medical,...               8.59
# 68                   A/P-Murum,Tal-Baramati,Dist-Pune               0.00
# 69       A/P- Ghadagewadi,  TQ- Baramati , Dist- pune               8.31
# 70                                                NaN               8.31
# 71  At/P Waghalwadi (Renukanagar),Tal.Baramati,Dis...               8.70
#
#     First year:Sem 2  Second year:Sem 1  Second year:Sem 2
# 0               8.60               9.80               9.90
# 1               8.14               9.32               9.82
# 2               6.61               9.14               9.14
# 3               7.30               8.90               9.20
# 4               7.45               9.05               9.40
# ..               ...                ...                ...
# 67              9.00               9.63               9.56
# 68              0.00               9.09               9.36
# 69              8.27               9.45               9.77
# 70              8.42               8.53               8.64
# 71              8.50               8.70               8.80
#
# [72 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Roll No', 'Name of Student', 'Email_ id', 'Contact No.', 'DOB',
#        'Address', 'First year: Sem 1', 'First year:Sem 2', 'Second year:Sem 1',
#        'Second year:Sem 2'],
#       dtype='object')

# %%
df.size  # rows * columns
# Out:
# 720

# %%
df.count()
# Out:
# Roll No              72
# Name of Student      72
# Email_ id            69
# Contact No.          67
# DOB                  65
# Address              65
# First year: Sem 1    72
# First year:Sem 2     72
# Second year:Sem 1    72
# Second year:Sem 2    72
# dtype: int64

# %%
df.describe()
# Out:
#         Contact No.  First year: Sem 1  First year:Sem 2  Second year:Sem 1  \
# count  6.700000e+01          72.000000         72.000000          72.000000
# mean   8.596981e+09           8.675833          8.927361           9.289167
# std    8.751060e+08          10.591957         10.580381           0.517199
# min    7.028331e+09           0.000000          0.000000           6.900000
# 25%    7.721387e+09           7.265000          7.765000           9.050000
# 50%    8.856895e+09           8.310000          8.420000           9.450000
# 75%    9.307663e+09           8.732500          9.100000           9.640000
# max    9.975813e+09          95.000000         95.000000           9.910000
#
#        Second year:Sem 2
# count          72.000000
# mean            9.371389
# std             0.486098
# min             7.200000
# 25%             9.137500
# 50%             9.450000
# 75%             9.725000
# max             9.950000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Roll No            72 non-null     object
#  1   Name of Student    72 non-null     object
#  2   Email_ id          69 non-null     object
#  3   Contact No.        67 non-null     float64
#  4   DOB                65 non-null     object
#  5   Address            65 non-null     object
#  6   First year: Sem 1  72 non-null     float64
#  7   First year:Sem 2   72 non-null     float64
#  8   Second year:Sem 1  72 non-null     float64
#  9   Second year:Sem 2  72 non-null     float64
# dtypes: float64(5), object(5)
# memory usage: 5.8+ KB

# %%
df.dtypes
# Out:
# Roll No               object
# Name of Student       object
# Email_ id             object
# Contact No.          float64
# DOB                   object
# Address               object
# First year: Sem 1    float64
# First year:Sem 2     float64
# Second year:Sem 1    float64
# Second year:Sem 2    float64
# dtype: object

# %%
'''
1] Scan all variables for missing values and inconsistencies. 
If there are missing values and/or inconsistencies, use any of the suitable techniques to deal with them.
'''


df.isna().sum()
# Out:
# Roll No              0
# Name of Student      0
# Email_ id            3
# Contact No.          5
# DOB                  7
# Address              7
# First year: Sem 1    0
# First year:Sem 2     0
# Second year:Sem 1    0
# Second year:Sem 2    0
# dtype: int64

# %%
# there is missing values in email id, contact no , dob,address  and here we  dicide to remove that null values 
df.dropna(inplace=True)
df.head(2)
# Out:
#   Roll No           Name of Student                        Email_ id  \
# 2   CO303  BHOSALE AISHWARYA SANJAY  bhosaleaishwarya7070@gmail.com
# 3   CO304  BUNGE SAKSHI DNYANESHWAR            bungesakshi@gmail.com
#
#     Contact No.         DOB                                    Address  \
# 2  8.530153e+09  07/07/2002  at post wanewadi, tal-Baramati dist-pune
# 3  9.579328e+09  04/05/2002        A/P: Murum Tal. Baramati Dist Pune.
#
#    First year: Sem 1  First year:Sem 2  Second year:Sem 1  Second year:Sem 2
# 2               6.61              6.61               9.14               9.14
# 3               7.20              7.30               8.90               9.20

# %%
df.shape
# Out:
# (63, 10)

# %%
df.isna().sum()
# Out:
# Roll No              0
# Name of Student      0
# Email_ id            0
# Contact No.          0
# DOB                  0
# Address              0
# First year: Sem 1    0
# First year:Sem 2     0
# Second year:Sem 1    0
# Second year:Sem 2    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Roll No', 'Name of Student', 'Email_ id', 'Contact No.', 'DOB',
#        'Address', 'First year: Sem 1', 'First year:Sem 2', 'Second year:Sem 1',
#        'Second year:Sem 2'],
#       dtype='object')

# %%
df_numerical = df.select_dtypes(include='number')
df_numerical
# Out:
#      Contact No.  First year: Sem 1  First year:Sem 2  Second year:Sem 1  \
# 2   8.530153e+09               6.61              6.61               9.14
# 3   9.579328e+09               7.20              7.30               8.90
# 4   9.130664e+09               7.05              7.45               9.05
# 5   9.309991e+09               7.50              8.00               7.91
# 6   7.219210e+09               8.27              8.50               9.68
# ..           ...                ...               ...                ...
# 66  9.561350e+09               9.54             10.00               9.45
# 67  7.057567e+09               8.59              9.00               9.63
# 68  7.249466e+09               0.00              0.00               9.09
# 69  9.156100e+09               8.31              8.27               9.45
# 71  7.028331e+09               8.70              8.50               8.70
#
#     Second year:Sem 2
# 2                9.14
# 3                9.20
# 4                9.40
# 5                7.84
# 6                9.14
# ..                ...
# 66               9.54
# 67               9.56
# 68               9.36
# 69               9.77
# 71               8.80
#
# [63 rows x 5 columns]

# %%
df_numerical.columns
# Out:
# Index(['Contact No.', 'First year: Sem 1', 'First year:Sem 2',
#        'Second year:Sem 1', 'Second year:Sem 2'],
#       dtype='object')

# %%
num_col = df_numerical.drop(['Contact No.'],axis=1)
num_col
# Out:
#     First year: Sem 1  First year:Sem 2  Second year:Sem 1  Second year:Sem 2
# 2                6.61              6.61               9.14               9.14
# 3                7.20              7.30               8.90               9.20
# 4                7.05              7.45               9.05               9.40
# 5                7.50              8.00               7.91               7.84
# 6                8.27              8.50               9.68               9.14
# ..                ...               ...                ...                ...
# 66               9.54             10.00               9.45               9.54
# 67               8.59              9.00               9.63               9.56
# 68               0.00              0.00               9.09               9.36
# 69               8.31              8.27               9.45               9.77
# 71               8.70              8.50               8.70               8.80
#
# [63 rows x 4 columns]

# %%
# Converting the roll numbers from TECOC342 --> 342
for i in df['Roll No'].iteritems():
    df['Roll No'][i[0]] = df['Roll No'][i[0]][-3:]
df.head(2)
# Out:
#   Roll No           Name of Student                        Email_ id  \
# 2     303  BHOSALE AISHWARYA SANJAY  bhosaleaishwarya7070@gmail.com
# 3     304  BUNGE SAKSHI DNYANESHWAR            bungesakshi@gmail.com
#
#     Contact No.         DOB                                    Address  \
# 2  8.530153e+09  07/07/2002  at post wanewadi, tal-Baramati dist-pune
# 3  9.579328e+09  04/05/2002        A/P: Murum Tal. Baramati Dist Pune.
#
#    First year: Sem 1  First year:Sem 2  Second year:Sem 1  Second year:Sem 2
# 2               6.61              6.61               9.14               9.14
# 3               7.20              7.30               8.90               9.20

# %%
df[:30]
# Out:
#    Roll No               Name of Student                        Email_ id  \
# 2      303      BHOSALE AISHWARYA SANJAY  bhosaleaishwarya7070@gmail.com
# 3      304      BUNGE SAKSHI DNYANESHWAR            bungesakshi@gmail.com
# 4      305        CHAVAN PUSHPAK MAHADEV      pushpakchavan798@gmail.com
# 5      306          DURGADE AVDHUT MOHAN      avdhutdurgade1120@gmail.com
# 6      307         GAWADE SWAPNALI UTTAM     swapnaligawade2002@gmail.com
# 7      308         GOLANDE ASHWINI DILIP       ashwinigolande24@gmail.com
# 8      309       JAGTAP APEKSHA NAVNATH       apekshajagtap2103@gmail.com
# 9      310      JAGTAP PRAJAKTA SADANAND      jagtapprajakta219@gmail.com
# 10     311      KHARADE KIRAN MACCHINDRA       kirankharade1110@gmail.com
# 11     312         KOLTE VISHAL NAYABRAO        vishalkolte4511@gmail.com
# 12     313            MANE ROHIT MAHADEV        rohitmane020188@gmail.com
# 13     314       DURGADE MAYURESH SANDIP        mayureshdurgade@gmail.com
# 14     315       MORE SOMESH DNYANESHWAR         someshmore2995@gmail.com
# 15     316         MORE SUKHADA RAJENDRA        sukhadamore8766@gmail.com
# 16     317        MUTEKAR HIMMAT BAPURAO       himmatmutekar478@gmail.com
# 17     318     NIGADE ADITYA DNYANESHWAR        adityanigade142@gmail.com
# 18     319               SANAS DIYA ATUL          diyasanas8503@gmail.com
# 19     320      SANKPAL REVATI SHANTARAM      revatisankpal6304@gmail.com
# 20     321       SHENDAGE NAMRATA RAMESH      shendagenamrata08@gmail.com
# 21     322          SHINDE AYUSH SHAHAJI           ayushinde123@gmail.com
# 22     323        SHINDE KAVERI RAJENDRA        shindekaveri274@gmail.com
# 23     324      SHRADDHA SHAHAJI GADEKAR     shraddhagadekar33@gmail.com
# 24     325          TAWARE PRASAD SANJAY        prasadtaware123@gmail.com
# 25     326         TEKAWADE YOGESH UTTAM        yogeshtekawade3@gmail.com
# 26     327          VIRAJ VIKRAM KHALATE         virajkhalate09@gmail.com
# 27     328           WAKASE SAKSHI ASHOK          wakasesakshi@gmail.com
# 28     329          SURVE DIVYA DEVEEDAS           divyasurve39@gmail.com
# 29     330    SUNNY HARISHCHANDRA SHINDE        sunnyshinde1103@gmail.com
# 30     331             KEWAT RUTIK SUNIL           rutikkewat99@gmail.com
# 31     332  RANANAVARE SHRADDHA SUDANRAO      ssrananavare2000@gmail.com
#
#      Contact No.          DOB  \
# 2   8.530153e+09   07/07/2002
# 3   9.579328e+09   04/05/2002
# 4   9.130664e+09   02/03/2002
# 5   9.309991e+09   16/05/2002
# 6   7.219210e+09   07/05/2002
# 7   9.370694e+09   24/12/2000
# 8   8.767256e+09   21/03/2002
# 9   8.856895e+09   27/10/2002
# 10  9.022976e+09   11/10/2002
# 11  7.378618e+09   09/05/2001
# 12  9.359626e+09   05/05/2002
# 13  8.669103e+09   13/07/2002
# 14  9.322909e+09   13/08/2002
# 15  8.010762e+09   01/05/2002
# 16  8.605101e+09   17/06/2002
# 17  9.307641e+09   21/12/2001
# 18  8.485018e+09   08/05/2003
# 19  8.421918e+09   04/01/2003
# 20  7.840947e+09   08/07/2003
# 21  8.805516e+09   02/07/2002
# 22  9.156913e+09   23/02/2002
# 23  8.855096e+09   29/06/2002
# 24  8.530493e+09   31/05/2002
# 25  9.112037e+09   06/02/2002
# 26  9.767906e+09   09/08/2002
# 27  9.623217e+09   20/06/2003
# 28  7.498072e+09   27/03/2002
# 29  9.307685e+09   11/03/2001
# 30  9.356555e+09   30/01/2001
# 31  9.322047e+09   29/07/2000
#
#                                               Address  First year: Sem 1  \
# 2           at post wanewadi, tal-Baramati dist-pune                6.61
# 3                 A/P: Murum Tal. Baramati Dist Pune.               7.20
# 4              At Post Jejuri Tal-Purandar Dist-Pune                7.05
# 5              At Post- Walhe Tal-Purandar Dist-Pune                7.50
# 6             A/P - Betwadi , Tal - Daund , Dist-Pune               8.27
# 7            A/P-Loni Bhapkar Tal- Baramati Dist-Pune               8.68
# 8                 A/P: Murum Tal. Baramati Dist Pune.               7.64
# 9                At Po Nira, Tal Purandhar, Dist Pune               9.09
# 10    At-Tadavale post-Kalaj Tal-Phaltan Dist-satara                7.45
# 11   At Post Takli Kolte TQ.Phulambri Dist.Aurangabad               9.00
# 12                 At Bhi.Sarola Tal/Dist- Osmanabad                9.00
# 13  At Post Walhe (Kamthwadi) Tal Purandar, Dist Pune               7.59
# 14          A/P Someshwarnagar tal-baramati,dist-pune               6.36
# 15  A/P. Nimbut ( Pharandenagar ), Tal Baramati, D...               8.04
# 16  A/P Soratewadi(Karchewadi) Tal-Baramati Dist-Pune               8.68
# 17      At post Dharampuri tal Malshiras Dist.Solapur               8.71
# 18  A/P - Sagunamata Nagar Malthan, Phaltan, Tal- ...               6.25
# 19           A/P- Murum , Tal- Phaltan, Dist -Satara                8.32
# 20         A/p Dhangarwadi ,old MIDC,Tal/dist. Satara               9.09
# 21           A/P - Wanewadi, Tal- Baramati, Dist-Pune               7.80
# 22           A/P - Wanewadi, Tal- Baramati, Dist-Pune               8.82
# 23        A/P Padegaon farm Tal- Phaltan Dist -Satara               8.68
# 24  A/P- Karanjepul Someshwarnagar, Tal- Baramati,...               9.42
# 25                A/P - Hol, Tal- Baramati,Dist- Pune               7.14
# 26                At Po Late, Tal Baramati, Dist Pune               8.81
# 27               A/P- Bawada,Tal- Indapur, Dist- Pune               7.31
# 28        A/p walhe(sukalwadi) tal-purandar dist-pune               7.00
# 29   At. Shindewadi po khunte Tal Phaltan Dist Satara               8.87
# 30  A/P- kirkatwadi , khadakwasla, Tal-Haveli , Di...               8.95
# 31         A/P Someshwarnagar Tal- Baramati Dist-Pune               9.13
#
#     First year:Sem 2  Second year:Sem 1  Second year:Sem 2
# 2               6.61               9.14               9.14
# 3               7.30               8.90               9.20
# 4               7.45               9.05               9.40
# 5               8.00               7.91               7.84
# 6               8.50               9.68               9.14
# 7               9.00               9.59               9.66
# 8               7.64               9.18               9.39
# 9               9.36               9.91               9.95
# 10              7.91               9.41               9.41
# 11              9.50               9.77               9.86
# 12              9.27               9.77               9.33
# 13              7.95               9.05               9.66
# 14              6.59               8.50               8.59
# 15              8.10               9.59               9.66
# 16              8.77               9.68               9.82
# 17              8.91               9.86               9.84
# 18              6.89               6.90               7.20
# 19              9.00               9.55               9.48
# 20              9.40               9.64               9.64
# 21              8.14               9.50               9.71
# 22              9.23               9.82               9.82
# 23              9.42               9.86               9.82
# 24              9.55               9.05               9.18
# 25              7.14               9.30               9.05
# 26              9.18               8.86               9.09
# 27              8.38               9.36               9.00
# 28              7.66               8.60               8.91
# 29              8.77               9.44               9.66
# 30              9.16               9.59               9.89
# 31              9.36               9.86               9.78

# %%
df.columns
# Out:
# Index(['Roll No', 'Name of Student', 'Email_ id', 'Contact No.', 'DOB',
#        'Address', 'First year: Sem 1', 'First year:Sem 2', 'Second year:Sem 1',
#        'Second year:Sem 2'],
#       dtype='object')

# %%
sns.set_style("whitegrid")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
sns.boxplot(data=data);
